# %% [markdown]
# <a href="https://colab.research.google.com/github/4hasan/Exercicios-PythonBrasil/blob/master/Mini_Jogo_do_Bixo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
# Lista vazia que vai ser preenchida com o for bixo
aposta1 = int(input('Aposte no número: '))
aposta2 = int(input('Aposte no número: '))

# Variavel que vai armazenar o valor da aposta
valor_aposta = float(input('Digite o valor da aposta R$: '))

# Lista que vai armazenar as duas apostas do jogador = aposta1 + aposta2
aposta = []

# metodo que vai jogar os valores de aposta1 + aposta 2 dentro da lista aposta
aposta.append(aposta1)
aposta.append(aposta2)

print(f'você apostou nesses números: {aposta}')

# Listas que vãa armazenar os números dos sorteio
sorteio = []
# Vai preencher 10 número aleatorios ente 1 e 100 dentro da listas de sorteio
contador = 2
for c in range(contador):
   numero1 = random.randint(10,100)
   sorteio.append(numero1)

# Vai imprimir na tela os valores sorteados
print(f"""
Os números sorteados são:
1 - {sorteio} 
""")
def validar_animal():
#Condição para verificar o Animal ganhador do primeiro sorteio:
  if sorteio[-1]>=1 and sorteio[-1] <= 4:
    print('O Vencedor do primeiro sorteio é o Avestruz')
  elif sorteio[-1]>=5 and sorteio[-1] <= 8:
    print('O Vencedor do primeiro sorteio é a Aguia')
  elif sorteio[-1]>=9 and sorteio[-1] <= 12:
    print('O Vencedor do primeiro sorteio é o Burro')
  elif sorteio[-1]>=13 and sorteio[-1] <= 16:
    print('O Vencedor do primeiro sorteio é a Borboleta')
  elif sorteio[-1]>=17 and sorteio[-1] <= 20:
    print('O Vencedor do primeiro sorteio é o Cachorro')
  elif sorteio[-1]>=21 and sorteio[-1] <= 24:
    print('O Vencedor do primeiro sorteio é a Cabra')
  elif sorteio[-1]>=25 and sorteio[-1] <= 28:
    print('O Vencedor do primeiro sorteio é o Carneiro')
  elif sorteio[-1]>=29 and sorteio[-1] <= 32:
    print('O Vencedor do primeiro sorteio é o Camelo')
  elif sorteio[-1]>=33 and sorteio[-1] <= 36:
    print('O Vencedor do primeiro sorteio é a Cobra')
  elif sorteio[-1]>=37 and sorteio[-1] <= 40:
    print('O Vencedor do primeiro sorteio é o Coelho')
  elif sorteio[-1]>=41 and sorteio[-1] <= 44:
    print('O Vencedor do primeiro sorteio é o Cavalo')
  elif sorteio[-1]>=45 and sorteio[-1] <= 48:
    print('O Vencedor do primeiro sorteio é o Elefante')
  elif sorteio[-1]>=49 and sorteio[-1] <= 52:
    print('O Vencedor do primeiro sorteio é o Galo')
  elif sorteio[-1]>=53 and sorteio[-1] <= 56:
    print('O Vencedor do primeiro sorteio é o Gato')
  elif sorteio[-1]>=57 and sorteio[-1] <= 60:
    print('O Vencedor do primeiro sorteio é o Jacaré')
  elif sorteio[-1]>=61 and sorteio[-1] <= 64:
    print('O Vencedor do primeiro sorteio é o Leão')
  elif sorteio[-1]>=65 and sorteio[-1] <= 68:
    print('O Vencedor do primeiro sorteio é o Macaco')
  elif sorteio[-1]>=69 and sorteio[-1] <= 72:
    print('O Vencedor do primeiro sorteio é o Porco')
  elif sorteio[-1]>=73 and sorteio[-1] <= 76:
    print('O Vencedor do primeiro sorteio é o Pavão')
  elif sorteio[-1]>=77 and sorteio[-1] <= 80:
    print('O Vencedor do primeiro sorteio é o Peru')
  elif sorteio[-1]>=81 and sorteio[-1] <= 84:
    print('O Vencedor do primeiro sorteio é o Touro')
  elif sorteio[-1]>=85 and sorteio[-1] <= 88:
    print('O Vencedor do primeiro sorteio é o Tigre')
  elif sorteio[-1]>=89 and sorteio[-1] <= 92:
    print('O Vencedor do primeiro sorteio é o Urso')
  elif sorteio[-1]>=92 and sorteio[-1] <= 96:
    print('O Vencedor do primeiro sorteio é o Veado')
  elif sorteio[-1]>=97 and sorteio[-1] <= 100:
    print('O Vencedor do primeiro sorteio é a Vaca')
  else:
    print('Animal inválido')
validar_animal()

def validar_numero_ganhador():
# Condição para verificar se o jogador tem algum número sorteado dentro da lista
  if aposta[-1] in sorteio:
    print('você tem um número sorteado')
    valor_aposta * 18
    print(f'Você foi premiado no valor de R$: {valor_aposta} ')
  else:
      print('Você não teve nenhum número sorteado')
validar_numero_ganhador()
# Out:
# Aposte no número: 45
# Aposte no número: 60
# Digite o valor da aposta R$: 10
# você apostou nesses números: [45, 60]
#
# Os números sorteados são:
# 1 - [99, 33]
#
# O Vencedor do primeiro sorteio é a Cobra
# Você não teve nenhum número sorteado
